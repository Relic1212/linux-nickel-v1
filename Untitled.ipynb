# %%
import parse
import graphviz
from parse import get_drvs
import json

# %%
def get_graph(drvs=None):
    
    if drvs is None:
        drvs=get_drvs()
    hbn = drvs['hashByName']
    dbh=drvs['drvByHash']
    g=graphviz.Digraph()

    for name in hbn:
        g.node(name,name)
        # g[name]={"name":name,"deps":[]}

    for name in hbn:
        hk=hbn[name]
        drv=json.loads(dbh[hk])
        name2=drv["name"]
        buildinput_hashes=drv['buildInputDrvs']
        buildinput_names=[ json.loads(dbh[h])["name"] for h in buildinput_hashes]

        for  bname in buildinput_names:
            g.edge(name,bname)

    return(g)
get_graph()

# %%
get_graph
# Out:
# {'bison-stage-1': {'name': 'bison-stage-1',
#   'deps': [{'name': 'musl-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'gnumake-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'busybox-stage-0',
#     'deps': [{'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'ccache-bin', 'deps': []},
#    {'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'm4-stage-1',
#     'deps': [{'name': 'musl-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'ccache-bin', 'deps': []},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'gnumake-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'gnumake-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'gnumake-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]}]},
#  'busybox-stage-0': {'name': 'busybox-stage-0',
#   'deps': [{'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'musl-stage-0', 'deps': []}]},
#  'ccache-bin': {'name': 'ccache-bin', 'deps': []},
#  'cmake-stage-1': {'name': 'cmake-stage-1',
#   'deps': [{'name': 'busybox-stage-0',
#     'deps': [{'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'ccache-bin', 'deps': []},
#    {'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'samurai-stage-1',
#     'deps': [{'name': 'musl-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'ccache-bin', 'deps': []},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'gnumake-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'gnumake-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'musl-stage-0', 'deps': []},
#    {'name': 'linux-headers-stage-1',
#     'deps': [{'name': 'musl-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'ccache-bin', 'deps': []},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'gnumake-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'flex-stage-1',
#       'deps': [{'name': 'musl-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'ccache-bin', 'deps': []},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'gnumake-stage-1',
#           'deps': [{'name': 'busybox-stage-0',
#             'deps': [{'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'ccache-bin', 'deps': []},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'm4-stage-1',
#         'deps': [{'name': 'musl-stage-1',
#           'deps': [{'name': 'busybox-stage-0',
#             'deps': [{'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'ccache-bin', 'deps': []},
#            {'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'gnumake-stage-1',
#             'deps': [{'name': 'busybox-stage-0',
#               'deps': [{'name': 'llvm-stage-0',
#                 'deps': [{'name': 'libssp-nonshared-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []},
#                    {'name': 'llvm-baselibs-stage-0',
#                     'deps': [{'name': 'linux-headers-stage-0',
#                       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                      {'name': 'musl-stage-0', 'deps': []}]}]},
#                  {'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'ccache-bin', 'deps': []},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'gnumake-stage-1',
#           'deps': [{'name': 'busybox-stage-0',
#             'deps': [{'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'gnumake-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'bison-stage-1',
#       'deps': [{'name': 'musl-stage-1',
#         'deps': [{'name': 'busybox-stage-0',
#           'deps': [{'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'ccache-bin', 'deps': []},
#          {'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'gnumake-stage-1',
#           'deps': [{'name': 'busybox-stage-0',
#             'deps': [{'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'ccache-bin', 'deps': []},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'm4-stage-1',
#         'deps': [{'name': 'musl-stage-1',
#           'deps': [{'name': 'busybox-stage-0',
#             'deps': [{'name': 'llvm-stage-0',
#               'deps': [{'name': 'libssp-nonshared-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []},
#                  {'name': 'llvm-baselibs-stage-0',
#                   'deps': [{'name': 'linux-headers-stage-0',
#                     'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                    {'name': 'musl-stage-0', 'deps': []}]}]},
#                {'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'ccache-bin', 'deps': []},
#            {'name': 'llvm-stage-0',
#             'deps': [{'name': 'libssp-nonshared-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []},
#                {'name': 'llvm-baselibs-stage-0',
#                 'deps': [{'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                  {'name': 'musl-stage-0', 'deps': []}]}]},
#              {'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'gnumake-stage-1',
#             'deps': [{'name': 'busybox-stage-0',
#               'deps': [{'name': 'llvm-stage-0',
#                 'deps': [{'name': 'libssp-nonshared-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []},
#                    {'name': 'llvm-baselibs-stage-0',
#                     'deps': [{'name': 'linux-headers-stage-0',
#                       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                      {'name': 'musl-stage-0', 'deps': []}]}]},
#                  {'name': 'linux-headers-stage-0',
#                   'deps': [{'name': 'musl-stage-0', 'deps': []}]},
# ...
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'musl-stage-0', 'deps': []}]},
#  'ninja-stage-1': {'name': 'ninja-stage-1',
#   'deps': [{'name': 'busybox-stage-0',
#     'deps': [{'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'python-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'gnumake-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'ccache-bin', 'deps': []},
#    {'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'musl-stage-0', 'deps': []}]},
#  'python-stage-1': {'name': 'python-stage-1',
#   'deps': [{'name': 'busybox-stage-0',
#     'deps': [{'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'ccache-bin', 'deps': []},
#    {'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'gnumake-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'musl-stage-0', 'deps': []}]},
#  'samurai-stage-1': {'name': 'samurai-stage-1',
#   'deps': [{'name': 'musl-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'ccache-bin', 'deps': []},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'gnumake-stage-1',
#       'deps': [{'name': 'busybox-stage-0',
#         'deps': [{'name': 'llvm-stage-0',
#           'deps': [{'name': 'libssp-nonshared-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []},
#              {'name': 'llvm-baselibs-stage-0',
#               'deps': [{'name': 'linux-headers-stage-0',
#                 'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#                {'name': 'musl-stage-0', 'deps': []}]}]},
#            {'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'busybox-stage-0',
#     'deps': [{'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]},
#    {'name': 'ccache-bin', 'deps': []},
#    {'name': 'llvm-stage-0',
#     'deps': [{'name': 'libssp-nonshared-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'linux-headers-stage-0',
#       'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'musl-stage-0', 'deps': []},
#      {'name': 'llvm-baselibs-stage-0',
#       'deps': [{'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []}]}]},
#    {'name': 'gnumake-stage-1',
#     'deps': [{'name': 'busybox-stage-0',
#       'deps': [{'name': 'llvm-stage-0',
#         'deps': [{'name': 'libssp-nonshared-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []},
#            {'name': 'llvm-baselibs-stage-0',
#             'deps': [{'name': 'linux-headers-stage-0',
#               'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#              {'name': 'musl-stage-0', 'deps': []}]}]},
#          {'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'musl-stage-0', 'deps': []}]},
#      {'name': 'llvm-stage-0',
#       'deps': [{'name': 'libssp-nonshared-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []},
#          {'name': 'llvm-baselibs-stage-0',
#           'deps': [{'name': 'linux-headers-stage-0',
#             'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#            {'name': 'musl-stage-0', 'deps': []}]}]},
#        {'name': 'linux-headers-stage-0',
#         'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#        {'name': 'musl-stage-0', 'deps': []},
#        {'name': 'llvm-baselibs-stage-0',
#         'deps': [{'name': 'linux-headers-stage-0',
#           'deps': [{'name': 'musl-stage-0', 'deps': []}]},
#          {'name': 'musl-stage-0', 'deps': []}]}]},
#      {'name': 'musl-stage-0', 'deps': []}]}]}}
