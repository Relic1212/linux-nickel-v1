# %%
import parse
import graphviz
from parse import get_drvs
import json

# %%
def get_graph(drvs=None):
    
    if drvs is None:
        drvs=get_drvs()
    hbn = drvs['hashByName']
    dbh=drvs['drvByHash']
    g=graphviz.Digraph()

    for name in hbn:
        g.node(name,name)
        # g[name]={"name":name,"deps":[]}

    for name in hbn:
        hk=hbn[name]
        drv=json.loads(dbh[hk])
        name2=drv["name"]
        buildinput_hashes=drv['buildInputDrvs']
        buildinput_names=[ json.loads(dbh[h])["name"] for h in buildinput_hashes]

        for  bname in buildinput_names:
            g.edge(name,bname)

    return(g)
get_graph()

# %%
g=get_graph()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 g=get_graph()
#
# Cell In[2], line 4, in get_graph(drvs)
#       1 def get_graph(drvs=None):
#       3     if drvs is None:
# ----> 4         drvs=get_drvs()
#       5     hbn = drvs['hashByName']
#       6     dbh=drvs['drvByHash']
#
# File /data/user/linux-nickel-v1/parse.py:38, in get_drvs()
#      36 def get_drvs():
#      37     fp="nickellib/pkgs.ncl"
# ---> 38     c=nickel_to_json(fp)
#      39     return c
#
# File /data/user/linux-nickel-v1/parse.py:14, in nickel_to_json(fp)
#      13 def nickel_to_json(fp):
# ---> 14     c=subprocess.run(["nickel", "export", fp , "--format", "json"],check=False,capture_output=True)
#      16     if c.returncode!=0:
#      17         print(c.stderr.decode())
#
# File /nix/store/wfbjq35kxs6x83c3ncpfxdyl5gbhdx4h-python3-3.12.6/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /nix/store/wfbjq35kxs6x83c3ncpfxdyl5gbhdx4h-python3-3.12.6/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /nix/store/wfbjq35kxs6x83c3ncpfxdyl5gbhdx4h-python3-3.12.6/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /nix/store/wfbjq35kxs6x83c3ncpfxdyl5gbhdx4h-python3-3.12.6/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
#g.render('graph', view=True)
